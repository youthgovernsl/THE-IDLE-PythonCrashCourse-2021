# %% [markdown]
# #<u><center> Conditionals and Loops

# %% [markdown]
# This notebook provides an introduction to the various types of conditionals and loops and the syntax used. The following topics will be covered.
#
# [1. Conditionals - (If statements / If-else statements / Elif statements / Nested if and if-else statements)](#1)
#
# [2. Loops - (For Loop / While Loop)](#2)

# %% [markdown]
# <a name="1"></a>
# #<u> Conditionals </u>
# Conditional statements are also known as decision-making statements. We use these statements when we want to execute a block of code when the given condition is true or false.

# %% [markdown]
# In Python, we can achieve decision making by using the below statements:
#
#
# 1.   If statements
# 2.   If-else statements
# 3.   Elif statements
# 4.   Nested if and if-else statements
# 5.   Elif ladder

# %% [markdown]
# ##If statements
# It decides whether certain statements need to be executed or not. This checks for a given condition where if the condition is true, then the set of code present inside the if block will be executed.

# %% [markdown]
#         If (Boolean expression): Block of code  #Set of statements to execute if the condition is true

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here, the condition will be evaluated to a Boolean expression (true or false). If the condition is true, then the statement or program present inside the 'if' block will be executed and if the condition is false, then the statements or program present inside the 'if' block will not be executed.

# %%
Num = 5
if(Num < 10):
  print('Number is smaller than 10')
print('This statements will always be executed')
# Out:
# Number is smaller than 10
# This statements will always be executed

# %% [markdown]
# ##If-else statements
# The statement itself tells that if a given condition is true, then execute the statements present inside the 'if' block. However, if the condition is false then execute the 'else' block.

# %% [markdown]
#         if(Boolean expression):
#             Block of code #Set of statements to execute if condition is true
#         else:
#             Block of code #Set of statements to execute if condition is false

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here, the condition will be evaluated to a Boolean expression (true or false). If the condition is true then the statements or program present inside the if block will be executed and if the condition is false then the statements or program present inside else block will be executed.

# %%
Num = 10
if (Num > 10):
    print("Number is greater than 10")
else:
    print("Number is 10")
# Out:
# Number is 10

# %% [markdown]
# ##Elif statements
# Elif statement is used to check multiple conditions only if the given if condition false. It’s similar to an if-else statement and the only difference is that in else we will not check the condition but in elif we will do check the condition.

# %% [markdown]
#         if (condition):
#            #Set of statement to execute if condition is true
#         elif (condition):
#            #Set of statements to be executed when if condition is false and elif condition is true
#         else:
#            #Set of statement to be executed when both if and elif conditions are false

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Num = 5
if Num > 0:
    print("Number is a positive number")
elif Num == 0:
    print("Number is equal to Zero")
else:
    print("Number is a negative number")
# Out:
# Number is a positive number

# %% [markdown]
# ##Nested if and if-else statements
# Nested if-else statements mean that an 'if' statement or if-else statement is present inside another 'if' or if-else block.

# %% [markdown]
#         if(condition):
#            #Statements to execute if condition is true
#            if(condition):
#               #Statements to execute if condition is true
#            #end of nested if
#         #end of if

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The above syntax clearly says that the 'if' block will contain another 'if' block in it and so on. 'If' block can contain ‘n’ number of if block inside it.

# %%
Num = 5
if Num >= 0:
    if Num == 0:
        print("Number is equal to Zero")
    else:
        print("Number is a positive number")
else:
    print("Number is a negative number")
# Out:
# Number is a positive number

# %% [markdown]
# <a name="2"></a>
# #<u> Loops </u>
# In Python, statements are executed in a sequential manner i.e. if our code is made up of several lines of code, then execution will start at the first line, followed by the second, and so on.
#
# However, there will be cases where we may want a block of code to execute several times until a condition is met.

# %% [markdown]
# **Python has two types of Loops:**
# 1.	For Loop - Iterator-based loop, which steps through the items of
# iterable objects like lists, tuples, string and executes a piece of code repeatedly for a number of times, based on the number of items in that iterable object.
#
# 2.	While Loop - Executes a block of statements repeatedly as long as the condition is TRUE. These two types of loops can be used inside each other to generate nested loops (more on this later).

# %% [markdown]
# ##For Loop
#
# The 'for' loop works well with iterable objects like lists, tuples, strings, etc. The 'for' loop is zero-indexed.
#
#         for in n:
# The condition in the 'for' loop stays TRUE only if it hasn’t iterated through all the items in the iterable object(n).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example 1:**

# %%
for x in range(6):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **Example 2:**
#
# Here we will print the following pyramid pattern with Star (asterisk).

# %% [markdown]
# Star Pattern: Equilateral triangle pattern with Star (asterisk)
#
#                  *
#                 *  *
#                *  *  *
#               *  *  *  *
#              *  *  *  *  *
#             *  *  *  *  *  *
#            *  *  *  *  *  *  *

# %%
print("Print equilateral triangle Pyramid using stars\n ")
size = 7
m = (2 * size) - 2
for i in range(0, size):
    for j in range(0, m):
        print(end=" ")
    m = m - 1  # decrementing m after each loop
    for j in range(0, i + 1):
        # printing full Triangle pyramid using stars
        print("* ", end=' ')
    print(" ")
# Out:
# Print equilateral triangle Pyramid using stars
#
#             *
#            *  *
#           *  *  *
#          *  *  *  *
#         *  *  *  *  *
#        *  *  *  *  *  *
#       *  *  *  *  *  *  *

# %% [markdown]
# ## While Loop
# The Python 'while' loop executes a block of statements repeatedly as long as the condition is TRUE. We notice that it is a bit similar to the 'if' statement. However, unlike the 'while' loop, the 'if' statement executes only once if its condition is TRUE.

# %% [markdown]
#         While condition:
#            expression(block of code)
# Unlike the 'for' loop, the 'while' loop doesn’t iterate over a sequence. It uses the comparison operators and booleans for its condition.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example 1:**

# %%
i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6

# %% [markdown]
# **Example 2:**
#
# Here the program takes a number as input from the user and calculates the average, as long as the user enters a positive number.

# %%
num=0
count=0
sum=0
while num>=0:
    num=int(input("Enter student's mark: -1 to exit\n"))
    if num>=0:
        count=count+1 #this counts number of inputs 
        sum=sum+num # this adds input number cumulatively. 
avg=sum/count
print ("Number of subjects considered:",count, "; Average:",avg)
# Out:
# Enter student's mark: -1 to exit
# 10
# Enter student's mark: -1 to exit
# 20
# Enter student's mark: -1 to exit
# 30
# Enter student's mark: -1 to exit
# -1
# Number of subjects considered: 3 ; Average: 20.0
